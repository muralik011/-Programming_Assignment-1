# %% [markdown]
# 1. Write a Python program to print &quot;Hello Python&quot;?

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# 2. Write a Python program to do arithmetical operations addition and division.?

# %%
a = int(input('Enter first number: '))
b = int(input('Enter second number: '))
print(f'a + b: {a + b}\na / b: {a / b}')
# Out:
# Enter first number: 1
# Enter second number: 2
# a + b: 3
# a / b: 0.5

# %% [markdown]
# 3. Write a Python program to find the area of a triangle?

# %%
base = float(input('Enter base length: '))
height = float(input('Enter height: '))
print(f'Area of triangle: {(base * height) / 2}')
# Out:
# Enter base length: 23
# Enter height: 66
# Area of triangle: 759.0

# %% [markdown]
# 4. Write a Python program to swap two variables

# %%
a, b = 2, 4
print(f'a, b: {a}, {b}')
temp = a
a = b
b = temp
print(f'a, b: {a}, {b}')
# Out:
# a, b: 2, 4
# a, b: 4, 2

# %% [markdown]
# 5. Write a Python program to generate a random number?

# %%
import numpy as np
#np.random.seed(42)
print(np.random.rand(1)[0]) # random number between 0 and 1
print(np.random.randint(0, 100, 1)[0]) # integer
# Out:
# 0.09997491581800289
# 74
